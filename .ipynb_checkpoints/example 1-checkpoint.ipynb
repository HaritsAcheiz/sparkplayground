# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Local-Jupyter-Spark") \
    .master("spark://172.18.0.2:7077") \
    .config("spark.jars", "shared-data/postgresql-42.7.5.jar") \
    .getOrCreate()
# Out:
# 25/09/29 13:44:52 WARN Utils: Your hostname, harits-m17xr4 resolves to a loopback address: 127.0.1.1; using 192.168.43.207 instead (on interface wlp2s0)
# 25/09/29 13:44:52 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 25/09/29 13:44:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://172.18.0.3/testing") \
    .option("dbtable", "employees") \
    .option("user", "postgresuser") \
    .option("password", "postgrespass") \
    .option("driver", "org.postgresql.Driver") \
    .load()

df.show()
# Out:
# +---+-------------+--------+-----------+
# | id|         name|  salary| department|
# +---+-------------+--------+-----------+
# |  1|Alice Johnson|75000.50|Engineering|
# |  2|    Bob Smith|68000.00|  Marketing|
# |  3|Charlie Brown|92000.75|Engineering|
# |  4|Alice Johnson|75000.50|Engineering|
# |  5|    Bob Smith|68000.00|  Marketing|
# |  6|Charlie Brown|92000.75|Engineering|
# +---+-------------+--------+-----------+
